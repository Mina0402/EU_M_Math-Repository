# %% [markdown]
# <a href="https://colab.research.google.com/github/Mina0402/EU_M_Math-Repository/blob/main/Chap03_Cm_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set()
# %matplotlib inline
# %precision 3

import requests, zipfile
from io import StringIO
import io

url='https://archive.ics.uci.edu/ml/machine-learning-databases/00356/student.zip'
r=requests.get(url, stream=True)
z=zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

# %%
ls
# Out:
# sample_data/  student-mat.csv  student-merge.R  student-por.csv  student.txt

# %%
wine_data = pd.read_csv(url, sep=';')
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
plt.hist(wine_data['fixed acidity'])
plt.xlabel('fixed acidity')
plt.ylabel('count')
plt.grid(True)

# %%
plt.hist(wine_data['volatile acidity'])
plt.xlabel('volatile acidity')
plt.ylabel('count')
plt.grid(True)

# %%
plt.hist(wine_data['citric acid'])
plt.xlabel('citric acid')
plt.ylabel('count')
plt.grid(True)

# %%
plt.hist(wine_data['residual sugar'])
plt.xlabel('residual sugar')
plt.ylabel('count')
plt.grid(True)

# %%
plt.hist(wine_data['chlorides'])
plt.xlabel('chlorides')
plt.ylabel('count')
plt.grid(True)

# %%
plt.hist(wine_data['free sulfur dioxide'])
plt.xlabel('free sulfur dioxide')
plt.ylabel('count')
plt.grid(True)

# %%
plt.hist(wine_data['total sulfur dioxide'])
plt.xlabel('total sulfur dioxide')
plt.ylabel('count')
plt.grid(True)

# %%
plt.hist(wine_data['density'])
plt.xlabel('density')
plt.ylabel('count')
plt.grid(True)

# %%
plt.hist(wine_data['pH'])
plt.xlabel('pH')
plt.ylabel('count')
plt.grid(True)

# %%
plt.hist(wine_data['sulphates'])
plt.xlabel('sulphates')
plt.ylabel('count')
plt.grid(True)

# %%
plt.hist(wine_data['alcohol'])
plt.xlabel('alcohol')
plt.ylabel('count')
plt.grid(True)

# %%
plt.hist(wine_data['quality'])
plt.xlabel('quality')
plt.ylabel('count')
plt.grid(True)

# %%
plt.plot(wine_data['fixed acidity'], wine_data['quality'], 'o')
plt.ylabel('fixed acidity')
plt.xlabel('quality')
plt.grid(True)

# %%
plt.plot(wine_data['volatile acidity'], wine_data['quality'], 'o')
plt.ylabel('volatile acidity')
plt.xlabel('quality')
plt.grid(True)

# %%
plt.plot(wine_data['citric acid'], wine_data['quality'], 'o')
plt.ylabel('citric acid')
plt.xlabel('quality')
plt.grid(True)

# %%
plt.plot(wine_data['residual sugar'], wine_data['quality'], 'o')
plt.ylabel('residual sugar')
plt.xlabel('quality')
plt.grid(True)

# %%
plt.plot(wine_data['chlorides'], wine_data['quality'], 'o')
plt.ylabel('chlorides')
plt.xlabel('quality')
plt.grid(True)

# %%
plt.plot(wine_data['free sulfur dioxide'], wine_data['quality'], 'o')
plt.ylabel('free sulfur dioxide')
plt.xlabel('quality')
plt.grid(True)

# %%
plt.plot(wine_data['total sulfur dioxide'], wine_data['quality'], 'o')
plt.ylabel('total sulfur dioxide')
plt.xlabel('quality')
plt.grid(True)

# %%
plt.plot(wine_data['density'], wine_data['quality'], 'o')
plt.ylabel('density')
plt.xlabel('quality')
plt.grid(True)

# %%
plt.plot(wine_data['pH'], wine_data['quality'], 'o')
plt.ylabel('pH')
plt.xlabel('quality')
plt.grid(True)

# %%
plt.plot(wine_data['sulphates'], wine_data['quality'], 'o')
plt.ylabel('sulphates')
plt.xlabel('quality')
plt.grid(True)

# %%
plt.plot(wine_data['alcohol'], wine_data['quality'], 'o')
plt.ylabel('alcohol')
plt.xlabel('quality')
plt.grid(True)

# %%
print('アルコール度数とワインの質は、正の相関があると思われる')
# Out:
# アルコール度数とワインの質は、正の相関があると思われる

# %% [markdown]
# <a href="https://colab.research.google.com/github/Mina0402/EU_M_Math-Repository/blob/main/Chap06_Ex_01_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# %precision 3
# Out:
# '%.3f'

# %%
#階層型インデックス
hier_df=DataFrame(
    np.arange(9).reshape((3,3)),
   index= [
    ['a','a','b'],
    [1,2,2]
    ],
    columns=[
        ['Osaka','Tokyo','Osaka'],
        ['Blue', 'Red','Red']
    ]
)
hier_df
# Out:
#     Osaka Tokyo Osaka
#      Blue   Red   Red
# a 1     0     1     2
#   2     3     4     5
# b 2     6     7     8

# %%
hier_df.index.names=['key1','key2']
hier_df.columns.names=['city','color']
hier_df
# Out:
# city      Osaka Tokyo Osaka
# color      Blue   Red   Red
# key1 key2
# a    1        0     1     2
#      2        3     4     5
# b    2        6     7     8

# %%
#カラムの絞り込み
hier_df['Osaka']
# Out:
# color      Blue  Red
# key1 key2
# a    1        0    2
#      2        3    5
# b    2        6    8

# %%
#インデックスを軸にした集計
hier_df.groupby(level='key2',axis=0).mean()
# Out:
# city  Osaka Tokyo Osaka
# color  Blue   Red   Red
# key2
# 1       0.0   1.0   2.0
# 2       4.5   5.5   6.5

# %%
hier_df.groupby(level='color',axis=1).mean()
# Out:
# color      Blue  Red
# key1 key2
# a    1      0.0  1.5
#      2      3.0  4.5
# b    2      6.0  7.5

# %%
hier_df.drop(['b'])
# Out:
# city      Osaka Tokyo Osaka
# color      Blue   Red   Red
# key1 key2
# a    1        0     1     2
#      2        3     4     5

# %%
#練習問題6-1
hier_df1=DataFrame(
    np.arange(12).reshape((3,4)),
    index=[['c','d','d'],[1,2,1,]],
    columns=[
        ['Kyoto','Nagoya','Hokkaido','Kyoto'],
        ['Yellow','Yellow','Red','Blue']
    ]
)

hier_df1.index.names=['key1','key2']
hier_df1.columns.names=['city','color']
hier_df1
# Out:
# city       Kyoto Nagoya Hokkaido Kyoto
# color     Yellow Yellow      Red  Blue
# key1 key2
# c    1         0      1        2     3
# d    2         4      5        6     7
#      1         8      9       10    11

# %%
hier_df1['Kyoto']
# Out:
# color      Yellow  Blue
# key1 key2
# c    1          0     3
# d    2          4     7
#      1          8    11

# %%
#練習問題6-2
hier_df1.groupby(level='city',axis=1).mean()
# Out:
# city       Hokkaido  Kyoto  Nagoya
# key1 key2
# c    1          2.0    1.5     1.0
# d    2          6.0    5.5     5.0
#      1         10.0    9.5     9.0

# %%
#練習問題6-3
hier_df1.groupby(level='key2',axis=0).mean()
# Out:
# city   Kyoto Nagoya Hokkaido Kyoto
# color Yellow Yellow      Red  Blue
# key2
# 1        4.0    5.0      6.0   7.0
# 2        4.0    5.0      6.0   7.0

# %%
data1 = {
    'id': ['100', '101', '102', '103', '104', '106', '108', '110', '111', '113'],
    'city': ['Tokyo','Osaka','Kyoto','Hokkaido','Tokyo','Tokyo','Osaka','Kyoto','Hokkaido','Tokyo'],
    'birth_year': [1990,1989,1992,1997,1982,1991,1988,1990,1995,1981],
    'name': ['Hiroshi','Akiko','Yuki','Satoru','Steeve','Mituru','Aoi','Tarou','Suguru','Mitsuo']
}
df1=DataFrame(data1)
df1
# Out:
#     id      city  birth_year     name
# 0  100     Tokyo        1990  Hiroshi
# 1  101     Osaka        1989    Akiko
# 2  102     Kyoto        1992     Yuki
# 3  103  Hokkaido        1997   Satoru
# 4  104     Tokyo        1982   Steeve
# 5  106     Tokyo        1991   Mituru
# 6  108     Osaka        1988      Aoi
# 7  110     Kyoto        1990    Tarou
# 8  111  Hokkaido        1995   Suguru
# 9  113     Tokyo        1981   Mitsuo

# %%
data2={
    'id':['100','101','102','105','107'],
    'math':[50,43,33,76,98],
    'english':[90,30,20,50,30],
    'sex':['M','F','F','M','M'],
    'index_num':[0,1,2,3,4]
}
df2=DataFrame(data2)
df2
# Out:
#     id  math  english sex  index_num
# 0  100    50       90   M          0
# 1  101    43       30   F          1
# 2  102    33       20   F          2
# 3  105    76       50   M          3
# 4  107    98       30   M          4

# %%
print('・結合テーブル')
pd.merge(df1,df2, on='id')
# Out:
# ・結合テーブル
#     id   city  birth_year     name  math  english sex  index_num
# 0  100  Tokyo        1990  Hiroshi    50       90   M          0
# 1  101  Osaka        1989    Akiko    43       30   F          1
# 2  102  Kyoto        1992     Yuki    33       20   F          2

# %%
#データのマージ(全結合)
pd.merge(df1,df2,how='outer')
# Out:
#      id      city  birth_year     name  math  english  sex  index_num
# 0   100     Tokyo      1990.0  Hiroshi  50.0     90.0    M        0.0
# 1   101     Osaka      1989.0    Akiko  43.0     30.0    F        1.0
# 2   102     Kyoto      1992.0     Yuki  33.0     20.0    F        2.0
# 3   103  Hokkaido      1997.0   Satoru   NaN      NaN  NaN        NaN
# 4   104     Tokyo      1982.0   Steeve   NaN      NaN  NaN        NaN
# 5   106     Tokyo      1991.0   Mituru   NaN      NaN  NaN        NaN
# 6   108     Osaka      1988.0      Aoi   NaN      NaN  NaN        NaN
# 7   110     Kyoto      1990.0    Tarou   NaN      NaN  NaN        NaN
# 8   111  Hokkaido      1995.0   Suguru   NaN      NaN  NaN        NaN
# 9   113     Tokyo      1981.0   Mitsuo   NaN      NaN  NaN        NaN
# 10  105       NaN         NaN      NaN  76.0     50.0    M        3.0
# 11  107       NaN         NaN      NaN  98.0     30.0    M        4.0

# %%
pd.merge(df1,df2,left_index=True, right_on='index_num')
# Out:
#   id_x      city  birth_year     name id_y  math  english sex  index_num
# 0  100     Tokyo        1990  Hiroshi  100    50       90   M          0
# 1  101     Osaka        1989    Akiko  101    43       30   F          1
# 2  102     Kyoto        1992     Yuki  102    33       20   F          2
# 3  103  Hokkaido        1997   Satoru  105    76       50   M          3
# 4  104     Tokyo        1982   Steeve  107    98       30   M          4

# %%
pd.merge(df1,df2,how='left')
# Out:
#     id      city  birth_year     name  math  english  sex  index_num
# 0  100     Tokyo        1990  Hiroshi  50.0     90.0    M        0.0
# 1  101     Osaka        1989    Akiko  43.0     30.0    F        1.0
# 2  102     Kyoto        1992     Yuki  33.0     20.0    F        2.0
# 3  103  Hokkaido        1997   Satoru   NaN      NaN  NaN        NaN
# 4  104     Tokyo        1982   Steeve   NaN      NaN  NaN        NaN
# 5  106     Tokyo        1991   Mituru   NaN      NaN  NaN        NaN
# 6  108     Osaka        1988      Aoi   NaN      NaN  NaN        NaN
# 7  110     Kyoto        1990    Tarou   NaN      NaN  NaN        NaN
# 8  111  Hokkaido        1995   Suguru   NaN      NaN  NaN        NaN
# 9  113     Tokyo        1981   Mitsuo   NaN      NaN  NaN        NaN

# %%
data3={
    'id':['117','118','119','120','125'],
    'city':['Chiba', 'Kanagawa','Tokyo','Fukuoka','Okinawa'],
    'birth_year':[1990,1989,1992,1997,1982],
    'name':['Suguru','Kouichi','Satochi','Yukie','Akari']
}
df3=DataFrame(data3)
df3
# Out:
#     id      city  birth_year     name
# 0  117     Chiba        1990   Suguru
# 1  118  Kanagawa        1989  Kouichi
# 2  119     Tokyo        1992  Satochi
# 3  120   Fukuoka        1997    Yukie
# 4  125   Okinawa        1982    Akari

# %%
#concat 縦結合
concat_data=pd.concat([df1,df3])
concat_data
# Out:
#     id      city  birth_year     name
# 0  100     Tokyo        1990  Hiroshi
# 1  101     Osaka        1989    Akiko
# 2  102     Kyoto        1992     Yuki
# 3  103  Hokkaido        1997   Satoru
# 4  104     Tokyo        1982   Steeve
# 5  106     Tokyo        1991   Mituru
# 6  108     Osaka        1988      Aoi
# 7  110     Kyoto        1990    Tarou
# 8  111  Hokkaido        1995   Suguru
# 9  113     Tokyo        1981   Mitsuo
# 0  117     Chiba        1990   Suguru
# 1  118  Kanagawa        1989  Kouichi
# 2  119     Tokyo        1992  Satochi
# 3  120   Fukuoka        1997    Yukie
# 4  125   Okinawa        1982    Akari

# %%
#練習問題6-4
data4={
    'id':['0','1','2','3','4','6','8','11','12','13'],
    'city':['Tokyo','Osaka','Kyoto','Hokkaido','Tokyo','Tokyo','Osaka','Kyoto','Hokkaido','Tokyo'],
    'birth_year':[1990, 1989,1992,1997,1982,1991,1988,1990,1995,1981],
    'name':['Hiroshi','Akiko','Yuki','Satoru','Steeve','Mituru','Aoi','Tarou','Suguru','Mitsuo']
}
df4=DataFrame(data4)
df4
# Out:
#    id      city  birth_year     name
# 0   0     Tokyo        1990  Hiroshi
# 1   1     Osaka        1989    Akiko
# 2   2     Kyoto        1992     Yuki
# 3   3  Hokkaido        1997   Satoru
# 4   4     Tokyo        1982   Steeve
# 5   6     Tokyo        1991   Mituru
# 6   8     Osaka        1988      Aoi
# 7  11     Kyoto        1990    Tarou
# 8  12  Hokkaido        1995   Suguru
# 9  13     Tokyo        1981   Mitsuo

# %%
data5={
    'id':['0','1','3','6','8'],
    'math':[20,30,50,70,90],
    'english':[30,50,50,70,20],
    'sex':['M','F','F','M','M'],
    'index_num':[0,1,2,3,4]
}
df5=DataFrame(data5)
df5
# Out:
#   id  math  english sex  index_num
# 0  0    20       30   M          0
# 1  1    30       50   F          1
# 2  3    50       50   F          2
# 3  6    70       70   M          3
# 4  8    90       20   M          4

# %%
pd.merge(df4,df5,on='id')
# Out:
#   id      city  birth_year     name  math  english sex  index_num
# 0  0     Tokyo        1990  Hiroshi    20       30   M          0
# 1  1     Osaka        1989    Akiko    30       50   F          1
# 2  3  Hokkaido        1997   Satoru    50       50   F          2
# 3  6     Tokyo        1991   Mituru    70       70   M          3
# 4  8     Osaka        1988      Aoi    90       20   M          4

# %%
#練習問題6-5
pd.merge(df4,df5,how='left')
# Out:
#    id      city  birth_year     name  math  english  sex  index_num
# 0   0     Tokyo        1990  Hiroshi  20.0     30.0    M        0.0
# 1   1     Osaka        1989    Akiko  30.0     50.0    F        1.0
# 2   2     Kyoto        1992     Yuki   NaN      NaN  NaN        NaN
# 3   3  Hokkaido        1997   Satoru  50.0     50.0    F        2.0
# 4   4     Tokyo        1982   Steeve   NaN      NaN  NaN        NaN
# 5   6     Tokyo        1991   Mituru  70.0     70.0    M        3.0
# 6   8     Osaka        1988      Aoi  90.0     20.0    M        4.0
# 7  11     Kyoto        1990    Tarou   NaN      NaN  NaN        NaN
# 8  12  Hokkaido        1995   Suguru   NaN      NaN  NaN        NaN
# 9  13     Tokyo        1981   Mitsuo   NaN      NaN  NaN        NaN

# %%
#練習問題6-6
data6={
    'id':['70','80','90','120','150'],
    'city':['Chiba', 'Kanagawa','Tokyo','Fukuoka','Okinawa'],
    'birth_year':[1980,1999,1995,1994,1994],
    'name':['Suguru','Kouichi','Satochi','Yukie','Akari']
}
df6=DataFrame(data6)
df6
# Out:
#     id      city  birth_year     name
# 0   70     Chiba        1980   Suguru
# 1   80  Kanagawa        1999  Kouichi
# 2   90     Tokyo        1995  Satochi
# 3  120   Fukuoka        1994    Yukie
# 4  150   Okinawa        1994    Akari

# %%
concat_data=pd.concat([df4,df6])
concat_data
# Out:
#     id      city  birth_year     name
# 0    0     Tokyo        1990  Hiroshi
# 1    1     Osaka        1989    Akiko
# 2    2     Kyoto        1992     Yuki
# 3    3  Hokkaido        1997   Satoru
# 4    4     Tokyo        1982   Steeve
# 5    6     Tokyo        1991   Mituru
# 6    8     Osaka        1988      Aoi
# 7   11     Kyoto        1990    Tarou
# 8   12  Hokkaido        1995   Suguru
# 9   13     Tokyo        1981   Mitsuo
# 0   70     Chiba        1980   Suguru
# 1   80  Kanagawa        1999  Kouichi
# 2   90     Tokyo        1995  Satochi
# 3  120   Fukuoka        1994    Yukie
# 4  150   Okinawa        1994    Akari

# %%
#ピポット操作
hier_df=DataFrame(
    np.arange(9).reshape((3,3)),
    index= [
        ['a','a','b'],
        [1,2,2]
    ],
    columns=[
        ['Osaka','Tokyo','Osaka'],
        ['Blue','Red','Red']
    ]
)
hier_df
# Out:
#     Osaka Tokyo Osaka
#      Blue   Red   Red
# a 1     0     1     2
#   2     3     4     5
# b 2     6     7     8

# %%
hier_df.stack()
# Out:
#           Osaka  Tokyo
# a 1 Blue      0    NaN
#     Red       2    1.0
#   2 Blue      3    NaN
#     Red       5    4.0
# b 2 Blue      6    NaN
#     Red       8    7.0

# %%
hier_df.stack().unstack()
# Out:
#     Osaka     Tokyo
#      Blue Red  Blue  Red
# a 1     0   2   NaN  1.0
#   2     3   5   NaN  4.0
# b 2     6   8   NaN  7.0

# %%
#重複データの除去
dupli_data=DataFrame({
    'col1':[1,1,2,3,4,4,6,6],
    'col2':['a','b','b','b','c','c','b','b']

})
print('・元のデータ')
dupli_data
# Out:
# ・元のデータ
#    col1 col2
# 0     1    a
# 1     1    b
# 2     2    b
# 3     3    b
# 4     4    c
# 5     4    c
# 6     6    b
# 7     6    b

# %%
dupli_data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# dtype: bool

# %%
#重複削除
dupli_data.drop_duplicates()
# Out:
#    col1 col2
# 0     1    a
# 1     1    b
# 2     2    b
# 3     3    b
# 4     4    c
# 6     6    b

# %%
#マッピング処理
city_map={'Tokyo':'Kanto',
          'Osaka':'Kansai',
          'Kyoto':'Kansai',
          'Hokkaido':'Hokkaido'
}
city_map
# Out:
# {'Tokyo': 'Kanto',
#  'Osaka': 'Kansai',
#  'Kyoto': 'Kansai',
#  'Hokkaido': 'Hokkaido'}

# %%
df1['region']=df1['city'].map(city_map)
df1
# Out:
#     id      city  birth_year     name    region
# 0  100     Tokyo        1990  Hiroshi     Kanto
# 1  101     Osaka        1989    Akiko    Kansai
# 2  102     Kyoto        1992     Yuki    Kansai
# 3  103  Hokkaido        1997   Satoru  Hokkaido
# 4  104     Tokyo        1982   Steeve     Kanto
# 5  106     Tokyo        1991   Mituru     Kanto
# 6  108     Osaka        1988      Aoi    Kansai
# 7  110     Kyoto        1990    Tarou    Kansai
# 8  111  Hokkaido        1995   Suguru  Hokkaido
# 9  113     Tokyo        1981   Mitsuo     Kanto

# %%
#カラムの中の1部のデータを取り出す
df1['up_two_num']=df1['birth_year'].map(lambda x:str(x)[0:3])
df1
# Out:
#     id      city  birth_year     name    region up_two_num
# 0  100     Tokyo        1990  Hiroshi     Kanto        199
# 1  101     Osaka        1989    Akiko    Kansai        198
# 2  102     Kyoto        1992     Yuki    Kansai        199
# 3  103  Hokkaido        1997   Satoru  Hokkaido        199
# 4  104     Tokyo        1982   Steeve     Kanto        198
# 5  106     Tokyo        1991   Mituru     Kanto        199
# 6  108     Osaka        1988      Aoi    Kansai        198
# 7  110     Kyoto        1990    Tarou    Kansai        199
# 8  111  Hokkaido        1995   Suguru  Hokkaido        199
# 9  113     Tokyo        1981   Mitsuo     Kanto        198

# %%
#ビン分割~離散的な範囲にデータを分散して集計する
birth_year_bins=[1980,1985,1990,1995,2000]

birth_year_cut_data=pd.cut(df1.birth_year,birth_year_bins)
birth_year_cut_data
# Out:
# 0    (1985, 1990]
# 1    (1985, 1990]
# 2    (1990, 1995]
# 3    (1995, 2000]
# 4    (1980, 1985]
# 5    (1990, 1995]
# 6    (1985, 1990]
# 7    (1985, 1990]
# 8    (1990, 1995]
# 9    (1980, 1985]
# Name: birth_year, dtype: category
# Categories (4, interval[int64, right]): [(1980, 1985] < (1985, 1990] < (1990, 1995] < (1995, 2000]]

# %%
pd.value_counts(birth_year_cut_data)
# Out:
# birth_year
# (1985, 1990]    4
# (1990, 1995]    3
# (1980, 1985]    2
# (1995, 2000]    1
# Name: count, dtype: int64

# %%
group_names=['early1980s', 'late1980s','early1990s','late1990s']
birth_year_cut_data=pd.cut(df1.birth_year,birth_year_bins,labels=group_names)
pd.value_counts(birth_year_cut_data)
# Out:
# birth_year
# late1980s     4
# early1990s    3
# early1980s    2
# late1990s     1
# Name: count, dtype: int64

# %%
pd.cut(df1.birth_year,2)
# Out:
# 0      (1989.0, 1997.0]
# 1    (1980.984, 1989.0]
# 2      (1989.0, 1997.0]
# 3      (1989.0, 1997.0]
# 4    (1980.984, 1989.0]
# 5      (1989.0, 1997.0]
# 6    (1980.984, 1989.0]
# 7      (1989.0, 1997.0]
# 8      (1989.0, 1997.0]
# 9    (1980.984, 1989.0]
# Name: birth_year, dtype: category
# Categories (2, interval[float64, right]): [(1980.984, 1989.0] < (1989.0, 1997.0]]

# %%
pd.value_counts(pd.qcut(df1.birth_year,2))
# Out:
# birth_year
# (1980.999, 1990.0]    6
# (1990.0, 1997.0]      4
# Name: count, dtype: int64

# %%
#練習問題6-7
from sklearn import linear_model

import requests, zipfile
import io
from io import StringIO


url='https://archive.ics.uci.edu/ml/machine-learning-databases/00356/student.zip'

r=requests.get(url, stream=True)

z=zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

# %%
ls
# Out:
# sample_data/  student-mat.csv  student-merge.R  student-por.csv  student.txt

# %%
df_math=pd.read_csv('student-mat.csv',sep=';')
df_math.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df_math['age_double']=df_math['age']*2
df_math.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3 age_double
# 0        3     4     1     1       3        6   5   6   6         36
# 1        3     3     1     1       3        4   5   5   6         34
# 2        3     2     2     3       3       10   7   8  10         30
# 3        2     2     1     1       5        2  15  14  15         30
# 4        3     2     1     2       5        4   6  10  10         32
#
# [5 rows x 34 columns]

# %%
#練習問題6-8
#分割の粒度
absences_bins=[0,1,5,100]

absences_cut_data=pd.cut(df_math.absences,absences_bins)
absences_cut_data
# Out:
# 0      (5.0, 100.0]
# 1        (1.0, 5.0]
# 2      (5.0, 100.0]
# 3        (1.0, 5.0]
# 4        (1.0, 5.0]
#            ...
# 390    (5.0, 100.0]
# 391      (1.0, 5.0]
# 392      (1.0, 5.0]
# 393             NaN
# 394      (1.0, 5.0]
# Name: absences, Length: 395, dtype: category
# Categories (3, interval[int64, right]): [(0, 1] < (1, 5] < (5, 100]]

# %%
pd.value_counts(absences_cut_data)
# Out:
# absences
# (5, 100]    146
# (1, 5]      131
# (0, 1]        3
# Name: count, dtype: int64

# %%
#練習問題6-9
group_names=['0-1', '1-5','5-100']
absences_cut_data=pd.cut(df_math.absences,absences_bins,labels=group_names)
pd.value_counts(absences_cut_data)
# Out:
# absences
# 5-100    146
# 1-5      131
# 0-1        3
# Name: count, dtype: int64

# %%
#データの集約とグループ演算
data1 = {
    'id': ['100', '101', '102', '103', '104', '106', '108', '110', '111', '113'],
    'city': ['Tokyo','Osaka','Kyoto','Hokkaido','Tokyo','Tokyo','Osaka','Kyoto','Hokkaido','Tokyo'],
    'birth_year': [1990,1989,1992,1997,1982,1991,1988,1990,1995,1981],
    'name': ['Hiroshi','Akiko','Yuki','Satoru','Steeve','Mituru','Aoi','Tarou','Suguru','Mitsuo']
}
df1=DataFrame(data1)
df1

city_map={'Tokyo':'Kanto',
          'Osaka':'Kansai',
          'Kyoto':'Kansai',
          'Hokkaido':'Hokkaido'
}

df1['region']=df1['city'].map(city_map)

df1['up_two_num']=df1['birth_year'].map(lambda x:str(x)[0:3])
df1
# Out:
#     id      city  birth_year     name    region up_two_num
# 0  100     Tokyo        1990  Hiroshi     Kanto        199
# 1  101     Osaka        1989    Akiko    Kansai        198
# 2  102     Kyoto        1992     Yuki    Kansai        199
# 3  103  Hokkaido        1997   Satoru  Hokkaido        199
# 4  104     Tokyo        1982   Steeve     Kanto        198
# 5  106     Tokyo        1991   Mituru     Kanto        199
# 6  108     Osaka        1988      Aoi    Kansai        198
# 7  110     Kyoto        1990    Tarou    Kansai        199
# 8  111  Hokkaido        1995   Suguru  Hokkaido        199
# 9  113     Tokyo        1981   Mitsuo     Kanto        198

# %%
#サイズ情報
df1.groupby('city').size()
# Out:
# city
# Hokkaido    2
# Kyoto       2
# Osaka       2
# Tokyo       4
# dtype: int64

# %%
#平均値
df1.groupby('city')['birth_year'].mean()
# Out:
# city
# Hokkaido    1996.0
# Kyoto       1991.0
# Osaka       1988.5
# Tokyo       1986.0
# Name: birth_year, dtype: float64

# %%
df1.groupby(['region', 'city'])['birth_year'].mean()
# Out:
# region    city
# Hokkaido  Hokkaido    1996.0
# Kansai    Kyoto       1991.0
#           Osaka       1988.5
# Kanto     Tokyo       1986.0
# Name: birth_year, dtype: float64

# %%
df1.groupby(['region', 'city'],as_index=False)['birth_year'].mean()
# Out:
#      region      city  birth_year
# 0  Hokkaido  Hokkaido      1996.0
# 1    Kansai     Kyoto      1991.0
# 2    Kansai     Osaka      1988.5
# 3     Kanto     Tokyo      1986.0

# %%
for group, subdf in df1.groupby('region'):
    print('---------------------------------------------------------------------')
    print('Region Name:[0]'.format(group))
    print(subdf)
# Out:
# ---------------------------------------------------------------------
# Region Name:[0]
#     id      city  birth_year    name    region up_two_num
# 3  103  Hokkaido        1997  Satoru  Hokkaido        199
# 8  111  Hokkaido        1995  Suguru  Hokkaido        199
# ---------------------------------------------------------------------
# Region Name:[0]
#     id   city  birth_year   name  region up_two_num
# 1  101  Osaka        1989  Akiko  Kansai        198
# 2  102  Kyoto        1992   Yuki  Kansai        199
# 6  108  Osaka        1988    Aoi  Kansai        198
# 7  110  Kyoto        1990  Tarou  Kansai        199
# ---------------------------------------------------------------------
# Region Name:[0]
#     id   city  birth_year     name region up_two_num
# 0  100  Tokyo        1990  Hiroshi  Kanto        199
# 4  104  Tokyo        1982   Steeve  Kanto        198
# 5  106  Tokyo        1991   Mituru  Kanto        199
# 9  113  Tokyo        1981   Mitsuo  Kanto        198

# %%
student_data_math=pd.read_csv('student-mat.csv',sep=';')

functions= ['count', 'mean', 'max', 'min']
grouped_student_data_math1=student_data_math.groupby(['sex', 'address'])
grouped_student_data_math1[['age','G1']].agg(functions)
# Out:
#               age                       G1
#             count       mean max min count       mean max min
# sex address
# F   R          44  16.977273  19  15    44  10.295455  19   6
#     U         164  16.664634  20  15   164  10.707317  18   4
# M   R          44  17.113636  21  15    44  10.659091  18   3
#     U         143  16.517483  22  15   143  11.405594  19   5

# %%
#練習問題6-10
df_math2=pd.read_csv('student-mat.csv',sep=';')
df_math2.groupby('school')['G1'].mean()
# Out:
# school
# GP    10.939828
# MS    10.673913
# Name: G1, dtype: float64

# %%
#練習問題6-11
df_math2.groupby(['school','sex'])['G1'].mean()
# Out:
# school  sex
# GP      F      10.579235
#         M      11.337349
# MS      F      10.920000
#         M      10.380952
# Name: G1, dtype: float64

# %%
df_math2.groupby(['school','sex'])['G2'].mean()
# Out:
# school  sex
# GP      F      10.398907
#         M      11.204819
# MS      F      10.320000
#         M      10.047619
# Name: G2, dtype: float64

# %%
df_math2.groupby(['school','sex'])['G3'].mean()
# Out:
# school  sex
# GP      F       9.972678
#         M      11.060241
# MS      F       9.920000
#         M       9.761905
# Name: G3, dtype: float64

# %%
#練習問題6-12
functions= ['max','min']
grouped_student_df_math2=df_math2.groupby(['school', 'sex'])
grouped_student_df_math2[['G1','G2','G3']].agg(functions)
# Out:
#             G1      G2      G3
#            max min max min max min
# school sex
# GP     F    18   4  18   0  19   0
#        M    19   3  19   0  20   0
# MS     F    19   6  18   5  19   0
#        M    15   6  16   5  16   0

# %%
#欠損データ
from numpy import nan as NA

df=pd.DataFrame(np.random.rand(10,4))

df.iloc[1,0]=NA
df.iloc[2:3,2]=NA
df.iloc[5:,3]=NA
df
# Out:
#           0         1         2         3
# 0  0.278842  0.493395  0.931049  0.371912
# 1       NaN  0.017889  0.190154  0.217282
# 2  0.491445  0.912858       NaN  0.073761
# 3  0.107148  0.381249  0.066956  0.078562
# 4  0.670382  0.205511  0.058561  0.748303
# 5  0.388447  0.347814  0.368632       NaN
# 6  0.327830  0.558258  0.824699       NaN
# 7  0.954305  0.984990  0.954461       NaN
# 8  0.928016  0.239737  0.469358       NaN
# 9  0.893881  0.023792  0.829005       NaN

# %%
#リストワイズ削除-NANがある行をすべて取り除く
df.dropna()
# Out:
#           0         1         2         3
# 0  0.278842  0.493395  0.931049  0.371912
# 3  0.107148  0.381249  0.066956  0.078562
# 4  0.670382  0.205511  0.058561  0.748303

# %%
#ペアワイズ削除-欠損している列のデータを無視し、利用可能なデータのみを使う
df[[0,1]].dropna()
# Out:
#           0         1
# 0  0.278842  0.493395
# 2  0.491445  0.912858
fx_jpusdata.head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-08   115.97

# %%
#参照
fx_jpusdata.loc['2016-04']
# Out:
#             DEXJPUS
# DATE
# 2016-04-01   112.06
# 2016-04-04   111.18
# 2016-04-05   110.26
# 2016-04-06   109.63
# 2016-04-07   107.98
# 2016-04-08   108.36
# 2016-04-11   107.96
# 2016-04-12   108.54
# 2016-04-13   109.21
# 2016-04-14   109.20
# 2016-04-15   108.76
# 2016-04-18   108.85
# 2016-04-19   109.16
# 2016-04-20   109.51
# 2016-04-21   109.41
# 2016-04-22   111.50
# 2016-04-25   111.08
# 2016-04-26   111.23
# 2016-04-27   111.26
# 2016-04-28   108.55
# 2016-04-29   106.90

# %%
fx_jpusdata.resample('M').last().head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-31   116.39
# 2001-02-28   117.28
# 2001-03-31   125.54
# 2001-04-30   123.57
# 2001-05-31   118.88

# %%
fx_jpusdata.resample('D').last().head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-06      NaN

# %%
fx_jpusdata.resample('D').ffill().head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-06   116.19

# %%
fx_jpusdata.shift(1).head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02      NaN
# 2001-01-03   114.73
# 2001-01-04   114.26
# 2001-01-05   115.47
# 2001-01-08   116.19

# %%
#練習問題6-16
annual_averages = fx_jpusdata.resample('Y').mean()

annual_averages
# Out:
#                DEXJPUS
# DATE
# 2001-12-31  121.568040
# 2002-12-31  125.220438
# 2003-12-31  115.938685
# 2004-12-31  108.150830
# 2005-12-31  110.106932
# 2006-12-31  116.312072
# 2007-12-31  117.762323
# 2008-12-31  103.390635
# 2009-12-31   93.682659
# 2010-12-31   87.781680
# 2011-12-31   79.696653
# 2012-12-31   79.818008
# 2013-12-31   97.597131
# 2014-12-31  105.739800
# 2015-12-31  121.049084
# 2016-12-31  108.656932

# %%
#移動平均
fx_jpusdata.head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-08   115.97

# %%
fx_jpusdata.rolling(3).mean().head()
# Out:
#                DEXJPUS
# DATE
# 2001-01-02         NaN
# 2001-01-03         NaN
# 2001-01-04  114.820000
# 2001-01-05  115.306667
# 2001-01-08  115.876667

# %%
fx_jpusdata.rolling(3).std().head()
# Out:
#              DEXJPUS
# DATE
# 2001-01-02       NaN
# 2001-01-03       NaN
# 2001-01-04  0.610000
# 2001-01-05  0.975312
# 2001-01-08  0.368963

# %%
#練習問題6-17
average20=fx_jpusdata.rolling(20).mean()
average20=fx_jpusdata.rolling(20).mean()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02      NaN
# 2001-01-03      NaN
# 2001-01-04      NaN
# 2001-01-05      NaN
# 2001-01-08      NaN
# ...             ...
# 2016-12-26      NaN
# 2016-12-27      NaN
# 2016-12-28      NaN
# 2016-12-29      NaN
# 2016-12-30      NaN
#
# [4174 rows x 1 columns]

# %%
average20.dropna()
# Out:
#              DEXJPUS
# DATE
# 2001-02-12  116.6910
# 2001-02-13  116.6920
# 2001-02-14  116.6070
# 2001-02-15  116.5015
# 2001-02-16  116.4130
# ...              ...
# 2016-11-08  104.1600
# 2016-11-09  104.1780
# 2016-11-10  104.3250
# 2016-12-22  115.1555
# 2016-12-23  115.3580
#
# [1593 rows x 1 columns]
